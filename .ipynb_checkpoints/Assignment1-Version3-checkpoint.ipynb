# %% [markdown]
# <h1><center>Data Structures and Algorithms</center></h1><h3><center>Assignment 1<br>Stephanie O'Neill, 15921808</center></h3><p><center>26th March 2021</center></p>

# %% [markdown]
# <h3>Table of Contents</h3>
# <ol><li>Introduction</li>
#     <li>Factorial Algorithm</li>
#     <li>Factorial implementations & Running times
#         <ul><li>Iterative</li>
#         <li>Non-tail recursive</li>
#         <li>Tail recursive</li>
#         <li>Comparison</li>
#         <li>Curve Fitting</li></ul>
#     </li>
#     <li>Search algorithms & Best/Worst Running times
#         <ul><li>Linear search</li>
#         <li>Binary search (iterative)</li>
#         <li>Curve Fitting</li></ul>
#     </li>
#     <li>Unit Testing</li>
#     <li>Conclusion</li>

# %% [markdown]
# <h1>1. Introduction</h1>
# <br>In this report I will be computing the running times for different implementations of the factorial algorithm with increasing input, and subsequently comparing these results to the time complexity of the respective implementation. <br>Following on from this, I will be looking at two different search algorithms: linear search and binary search (iterative). I will investigate how they perform with increasing input, and also compare the best and worst case running times. These will then be compared to the theoretical time complexities: Big-O (worst case/upperboun) and Big-Ω (best cast/lowerbound). These can be determined by looking at the number of operations and activations in the algorithm itself.

# %% [markdown]
# <h1>2. Factorial Algorithm</h1>

# %% [markdown]
# The algorithm for factorial is as follows:
# <center>Step 1: Declare N and F as integer variables.</center>
#
# <center>Step 2: Initialize F=1.</center>
#
# <center>Step 2: Enter the value of N.</center>
#
# <center>Step 3: Check whether N>0, if not then F=1.</center>
#
# <center>Step 4: If yes then, F=F*N</center>
#
# <center>Step 5: Decrease the value of N by 1.</center>
#
# <center>Step 6: Repeat step 4 and 5 until N=0.</center>
#
# <center>Step 7: Now print the value of F.</center>
#
# <center>The value of F will be the factorial of N(number).</center>

# %%
import time
import unittest
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from scipy import stats

# %% [markdown]
# Below is a function that computes the running times of a function being called with increasing input. The function works by timing a function call <i>100 times</i> for an input <i>x</i>, and then takes the minimum value out of those 100 times and stores it in an array <b>'timearray'</b>. (We take the minimum value because the running time is not only dependant on the time complexity - it can also be affected by the computer's memory and other resources. Therefore taking the minimum is in the aim of getting close to the 'true' running time).
# <br>The value of the input x is then increased by 1, and the function is called and timed again 100 times and so on. This function, <i>get_timings_fact( func )</i>,  returns 'timearray', and <b>'inputsize'</b> which is an array that stores the corresponding input values for the times. This enables the two arrays to then be plotted against each other.

# %%
def get_timings_fact(func, N = 400):
    '''Function to get the running times of another function 
    being passed an increasing input/argument value'''
    loops = 100                    # number of loops for each input size
    
    temparray = [None] * loops     # to contain the timing of each loop
    timearray = [None] * N         # to contain the min value of each instance of temparray
    inputsize = [None] * N         # to contain the respective increasing values being passed to the factorial function
    
    for x in range(N):   
        
        for i in range(loops):
            
            # timing section
            start = time.perf_counter()
            func(x)
            end = time.perf_counter()
            elapsedtime = end - start
            
            # putting the time of each loop into an array, to then be able to take the min as the 'true' running time
            temparray[i] = elapsedtime
            
        # this array will be for the y-axis
        timearray[x] = min(temparray)
        
        # this array will be for the x-axis
        inputsize[x] = x
    
    return timearray, inputsize

# %% [markdown]
# <h1>3. Factorial implementations & Running times</h1>

# %% [markdown]
# <h3><i>Iterative implementation</i></h3>
# <br>In these implementations, I will also be calculating the number of operations for both best and worst cases of the function. This will enable us to determine Big-O and Big-Ω.
#
# $$ Running time = operations * activations $$
# <br>ie. Each operation in a function has a certain number of activations. The equation above tells us the time complexity of each operation. Summing these gives the time complexity of the function.

# %%
# Operations ------------------------> Best case   Worst case 

def fact_iter(n):                      
    '''Implementation of the Factorial 
    algorithm using the Iterative approach'''
    
    if (n == 0):                        # 1 op
        return 1                        # 1 op
    else:                                            
        factorial = 1                               # 1 op
        for i in range(1, n+1):                     # 2n ops
            factorial *= i                          # n ops
        return factorial                            # 1 op

#                                     ------------------------
# Sum of operation:                     # 2 ops     # 3n + 3 
# Corresponds to:                       # Ω(1)      # O(n)

# %%
res = get_timings_fact(fact_iter)
x_fact_iter = res[1]
y_fact_iter = res[0]

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Input size')
ax.set_ylabel('Running Time [s]')
ax.set_title('Running times: Iterative Factorial')
plt.plot(x_fact_iter, y_fact_iter, label='Iterative Factorial')


plt.legend()
plt.savefig('fact-iterative.png')
plt.show()

# %% [markdown]
# <h3><i>Non-tail Recursive implementation</i></h3>

# %%
# Operations ------------------------------------> Best case   Worst case 

def fact_recursive_non_tail(n):
    '''Implementation of the Factorial algorithm 
    using the Recursive Non-Tail approach'''
    
    if (n == 0):                                    # 1 op
        return 1        # (base case)               # 1 op
    return n * fact_recursive_non_tail(n-1)                     # 3n ops
#                                                ------------------------
# Sum of operations:                                # 2 ops     # 3n ops
# Corresponds to:                                   # Ω(1)      # O(n)

# %%
res = get_timings_fact(fact_recursive_non_tail)
x_fact_nontail = res[1]
y_fact_nontail = res[0]

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Input size')
ax.set_ylabel('Running Time [s]')
ax.set_title('Running times: Non-tail recursive Factorial')
plt.plot(x_fact_nontail, y_fact_nontail, label='Non-Tail Recursive Factorial')


plt.legend()
plt.savefig('fact-nontail-recursive.png')
plt.show()

# %% [markdown]
# <h3><i>Tail Recursive implementation</i></h3>

# %% [markdown]
# This implementation uses an accumulator <i>a</i> to store the result of the recursive calls.

# %%
# Operations ------------------------------------> Best case   Worst case 

def fact_recursive_tail(n, a = 1):
    '''Implementation of the Factorial algorithm 
    using the Tail Recursive approach'''
    
    if (n == 0):                                    # 1 op
        return a        # (base case)               # 1 op
    return fact_recursive_tail(n-1, a*n)                        # n ops
#                                                ------------------------
# Sum of operation:                                 # 2 ops     # n ops
# Corresponds to:                                   # Ω(1)      # O(n)

# %%
res = get_timings_fact(fact_recursive_tail)
x_fact_tail = res[1]
y_fact_tail = res[0]

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Input size')
ax.set_ylabel('Running Time [s]')
ax.set_title('Running times: Tail recursive Factorial')
plt.plot(x_fact_tail, y_fact_tail, label='Tail Recursive Factorial')



plt.legend()
plt.show()
plt.savefig('fact-tail-recursive.png')

# %% [markdown]
# <h3><i>Comparing running times of the 3 different factorial implementations</i></h3>

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Input size')
ax.set_ylabel('Running Time [s]')
ax.set_title('Running times: Factorial')
plt.plot(x_fact_tail, y_fact_tail, label='Tail Recursive Factorial')
plt.plot(x_fact_nontail, y_fact_nontail, label='Non-Tail Recursive Factorial')
plt.plot(x_fact_iter, y_fact_iter, label='Iterative Factorial')


plt.legend()
plt.savefig('fact-comparison.png')
plt.show()

# %% [markdown]
# The graph above compares the raw timing data collected of the 3 different factorial implementations when increasing the input. These trends will be discussed next in the Curve Fitting section using linear regression to aid our analysis.

# %% [markdown]
# <h3><i>Curve Fitting</i></h3>
# <br>I have written the function below to plot the best line of fit, using the Seaborn module that computes a linear regression model for each data set.

# %%
def plot_linear_regression(dataframes, labels, title = ''):
    '''Function that plots the best line of fit using linear regression'''
    
    colors = iter(['xkcd:blue with a hint of purple', 'green', 'red'])
    i = 0       # for iterating through the labels list
    
    # Initiating two arrays in which to store the stats 
    slopes = []
    intercepts = []
    
    # Plotting each dataframe
    for df in dataframes:
        color = next(colors)
        
        # Using stats.lingress to get the values for the linear regression model
        slope, intercept, r_value, p_value, std_err = stats.linregress(df[df.columns[0]],df[df.columns[1]])
        
        # Plotting using the Seaborn regplot function
        ax = sns.regplot(x=str(df.columns[0]), y=str(df.columns[1]), 
                         data=df, marker='+', line_kws={"color": color}, 
                         scatter_kws={'color':color,'alpha':0.3}, 
                         label=labels[i]+":   y = {0:.3g}x + {1:.3g}".format(slope,intercept))
        
        slopes.append(slope)
        intercepts.append(intercept)
        i+=1       # next label in the list
        
    ax.set(xlabel='Input size', ylabel='Running time [s]')
    ax.set_title(title)
    plt.legend()
    plt.savefig(title)
    plt.show()
    return slopes, intercepts

# %%
# Creating dataframes for each of the factorial results

df_fact_iter = pd.DataFrame(list(zip(x_fact_iter, y_fact_iter)), columns = ['x_fact_iter', 'y_fact_iter'])
df_fact_nontail = pd.DataFrame(list(zip(x_fact_nontail, y_fact_nontail)), columns = ['x_fact_nontail', 'y_fact_nontail'])
df_fact_tail = pd.DataFrame(list(zip(x_fact_tail, y_fact_tail)), columns = ['x_fact_tail', 'y_fact_tail'])

# %%
# Calling the plot function

dataframes = [df_fact_iter, df_fact_nontail, df_fact_tail]
labels=['Iterative', 'Non-tail recursive', 'Tail recursive']
plot1 = plot_linear_regression(dataframes, labels, 
                       title = 'Linear regression models of Factorial functions')

print('Equations of linear regression model:')
for i in range(3):
    print("{:<20}\ty = {:.3g}x + {:.3g}".format(labels[i], plot1[0][i], plot1[1][i]))
# Out:
# Equations of linear regression model:
# Iterative           	y = 1.48e-07x + -4.52e-06
# Non-tail recursive  	y = 2.96e-07x + -7.71e-06
# Tail recursive      	y = 3.43e-07x + -6.92e-06

# %% [markdown]
# In the graph produced above, we can start by noticing that all 3 implementations of the factorial algorithm share a similar positive linear trend. Iterative linear search appears to have the smallest gradient, while Tail recursive has the largest (ie. steepest). This is in line with the determined time complexity O(n).

# %% [markdown]
# <h1>4. Search Algorithms & Best/Worst Running times</h1>

# %% [markdown]
# In this section I will be looking at two different Search algorithms: <b>Linear search</b> and <b>Binary search (Iterative)</b>.
# <br>I will be investigating their respective best/worst running times, and comparing these to the time complexity.
#
# <br>The <i>get_timings_search()</i> function below is a variation of the <i>get_timings_fact()</i> function seen in Section 3. It accounts for the fact that now, increasing input means increasing the length/size of the input list. The search functions take <b>sequences</b> (lists) as input and outputs an integer value (ie. the index of the target), whereas the factorial functions took a single number as input and output a numeric value.

# %%
def get_timings_search(func, seq, target, case = None, N = 1000):
    '''Function to get the running times of a function with an increasing sequence as input. 
    Sequence increases up to a size N.'''
    
    loops = 100      # number of loops to time for each sequence length

    temparray = [None] * loops    # to contain the timing of each loop
    timearray = [None] * N        # to contain the min value of each new temparray
    inputsize = [None] * N        # contains the respective length of sequence (for y-axis)

    for x in range(N):
        for i in range(loops):

            # timing section
            start = time.perf_counter()
            func(seq, target)
            end = time.perf_counter()
            elapsedtime = end - start

            # putting the time of each loop into an array, to then be able to take the min of this array as the 'true' running time
            temparray[i] = elapsedtime

        # taking the minimum time in the temparray - this will be the y-axis
        timearray[x] = min(temparray)

        # this array will be for the x-axis
        inputsize[x] = len(seq)

        # increase size of sequence
        seq.append(seq[-1]+1)
        
        # for binary search iterative BEST case - target always needs to be the mid element of the sequence
        if case == 'BinaryBest':
            target = get_middle_element(seq)
            
        # for linear search WOSRT case - target always needs to be the last element
        elif case == 'LinearWorst':
            target = seq[-1]
            
            
    return timearray, inputsize

# %% [markdown]
# <h3><i>Linear Search</i></h3>

# %% [markdown]
# <b>Implementation</b>

# %%
# Operations -----------------------------------------> Best case   Worst case 


def linearSearch(sequence, target):
    '''Implementation of linear search algorithm'''
    for i in sequence:                                  # 1 op        # n ops
        if i == target:                                 # 1 op        # n ops
            return sequence.index(i)                    # 2 ops       
    return -1                                                         # 1 op
#                                                      ------------------------
# Sum of operations:                                    # 4 ops       # 2n + 1 ops
# Corresponds to:                                       # Ω(1)        # O(n)

# %% [markdown]
# <b>(Linear search) Best and worst case running time</b>

# %%
# Linear Search: Worst-case and Best-case Running times
seq = list(y_fact_iter)
last_element = seq[-1]
res = get_timings_search(linearSearch, seq, last_element, case = 'LinearWorst')
x_linear_worst = res[1]
y_linear_worst = res[0]

seq = list(y_fact_iter)
first_element = seq[0]
res = get_timings_search(linearSearch, seq, first_element)
x_linear_best = res[1]
y_linear_best = res[0]

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Input size')
ax.set_ylabel('Running Time [s]')
ax.set_title('Running times: Linear Search')
plt.plot(x_linear_worst, y_linear_worst, label='Worst case')
plt.plot(x_linear_best, y_linear_best, label='Best case')

plt.legend()
plt.savefig('search-linear-bestworst.png')
plt.show()

# %% [markdown]
# In the above graph, we can see two clear relationships. I will be analysing this in the curve fitting section.

# %% [markdown]
# <h3><i>Binary Search (Iterative approach)</i></h3>

# %% [markdown]
# <b>Implementation</b>

# %%
# Operations --------------------------------------------> Best case   Worst case 

def binarySearchIterative(sequence, target):
    '''Implementation of iterative binary search algorithm'''
    
    left, right = 0, len(sequence)-1                       # 4 ops       # 4 ops
    while left <= right:                                   # 1 op        # k ops   where k is the number of times the sequence is halved
  
        mid = (right + left) // 2;                         # 3 ops       # 3k ops
          
        # Check if target is present at mid 
        if sequence[mid] == target:                        # 2 ops       # 2k ops
            return mid                                     # 1 op
  
        # If target is greater, ignore left half 
        if sequence[mid] < target:                                       # 2k ops
            left = mid + 1                                               # 2k ops
  
        # If target is smaller, ignore right half 
        elif sequence[mid] > target:                                     
            right = mid - 1
      
    # If we reach here, then the element 
    # was not present 
    return -1                                                            # 1 op
#                                                        -------------------------
# Sum of operation:                                        # 11 ops      # 10k + 4 ops
# Corresponds to:                                          # Ω(1)        # O(log(n)) -> see below

# %% [markdown]
# Because with each search the length of the sequence is divided by 2, therefore k is the <i>number of times</i> the sequence is halved: $$ n/2^1 -> n/2^2 -> n/2^3 ->... -> n/2^k$$
# <br>Given that the binary search needs to search through the list k times, we find that in the worst case 10k+4 operations are activated (see binarySearchIterative function), which was can take to be k. The relationship of k to n (the length of the sequence) as demonstrated above is:
# $$ n / 2^k = 1 $$
# $$ n = 2^k $$
# $$ k = log_2(n)$$
#
# Therefore the time complexity of this binary search implementation is: $$O(log_2(n))$$

# %%
def get_middle_element(sequence):
    '''For Binary Search Best Case: Finding the mid element in the sequence. 
    (In the same way the binarySearchIterative function does)'''
    left = 0
    right = len(sequence)-1
    mid = (right + left) // 2
    return sequence[mid]

# %% [markdown]
# <b>(Binary Search Iterative) Worst-case and Best-case Running times</b>

# %%
upperbound = 5000     # setting the max length of the sequence to be timed

# Worst case

seq = list(y_fact_iter)  # using the output list of a factorial function as our input sequence
seq.sort()               # sequence must be sorted for binary search
target = -15             # target is a number not in the sequence (eg. any negative number)   

res = get_timings_search(binarySearchIterative, seq, target, case = None, N = upperbound)
x_binary_worst = res[1]
y_binary_worst = res[0]

# Best case

seq = list(y_fact_iter)  
seq.sort()
target = get_middle_element(seq)    # target is the middle element of the sequence
res = get_timings_search(binarySearchIterative, seq, target, case ='BinaryBest', N = upperbound)
x_binary_best = res[1]
y_binary_best = res[0]

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Input size')
ax.set_ylabel('Running Time [s]')
ax.set_title('Running times: Binary Search Iterative')
plt.plot(x_binary_worst, y_binary_worst, label='Worst case')
plt.plot(x_binary_best, y_binary_best, label='Best case')

plt.legend()
plt.savefig('search-binary-bestworst.png')
plt.show()

# %% [markdown]
# In the graph produced above, we can notice two distinct trends. Let us fit curves in order to analyse these graphs.

# %% [markdown]
# <h3><i>Curve Fitting</i></h3>

# %% [markdown]
# <li><b>Linear Search</b><i> - Best and Worst case</i></li>
# <br>Using the function defined in Section 4, I will be using linear regression to find the best line of fit for the best and worst case running times of Linear Search.

# %%
# Creating dataframes for both Best and Worst case running times computed for the Linear Search algorithm 

df_linear_worst = pd.DataFrame(list(zip(x_linear_worst, y_linear_worst)), columns = ['x_linear_worst', 'y_linear_worst'])
df_linear_best = pd.DataFrame(list(zip(x_linear_best, y_linear_best)), columns = ['x_linear_best', 'y_linear_best'])

# Calling the plot function

labels = ['Worst case', 'Best case']
dataframes = [df_linear_worst, df_linear_best]
plot2 = plot_linear_regression(dataframes, labels, title = 'Linear regression models of Linear Search')

# Printing the equations

print('Equations of linear regression model:')
for i in range(2):
    print("{:<20}\ty = {:.3g}x + {:.3g}".format(labels[i], plot2[0][i], plot2[1][i]))
# Out:
# Equations of linear regression model:
# Worst case          	y = 5.01e-08x + 4.97e-08
# Best case           	y = -9.7e-13x + 3.55e-07

# %% [markdown]
# For the best case of linear search, ie. searching for the first element in the list, there is a very clear linear relationship between the running time and the input size (the size of the sequence being searched). This is in line with Big-O (determined by counting the number of operations in the algorithm): $$O(n)$$
# <br>The best case is also in line with the Big-Ω: $$Ω(1)$$

# %% [markdown]
# <li><b>Binary Search</b><i> - Best case</i></li>
# <br>For the best case running time, I will be using the same function to plot the best line of fit using linear regression.

# %%
# Creating dataframe

df_binary_best = pd.DataFrame(list(zip(x_binary_best, y_binary_best)),
                               columns = ['x_binary_best', 'y_binary_best'])

# Calling the plot function
labels = ['Best case']
dataframes = [df_binary_best]
plot3 = plot_linear_regression(dataframes, labels, title = '       Best Case running times - Binary Search (iterative)')

# Printing the equation

print('Equation of linear regression model:')
print("{:<20}\ty = {:.3g}x + {:.3g}".format(labels[0], plot3[0][0], plot3[1][0]))
# Out:
# Equation of linear regression model:
# Best case           	y = -1.4e-13x + 5.06e-07

# %% [markdown]
# The fitted line in the graph above estimates a slight gradient, perhaps due to spikes in timing caused by iregularities in computation, but overall it is very close to being constant time. This is in line with the Ω(1) complexity expected.

# %% [markdown]
# <li><b>Binary Search</b><i> - Worst case</i></li>
# <br>Now, for the worst case running times of Binary Search (iterative), I will be using a different plotting function. I will be using the Seaborn <i>lmplot()</i> function. This function is similar to regplot() but allows us to estimate a linear regression of the form y ~ log(x), but plot the scatterplot and regression model in the input space.
# <br>(cf. https://seaborn.pydata.org/generated/seaborn.lmplot.html)

# %%
df_binary_worst = pd.DataFrame(list(zip(x_binary_worst, y_binary_worst)),
                               columns = ['x_binary_worst', 'y_binary_worst'])

# %%
ax = sns.lmplot(x="x_binary_worst", y="y_binary_worst", data=df_binary_worst,
           logx=True, ci=None,line_kws={"color": 'r'},markers='+', scatter_kws={"s": 80, 'alpha':0.05})

ax.set(xlabel='Input size', ylabel='Running time [s]')
ax.fig.suptitle("         Worst case running time - Binary Search", fontsize=12)
#plt.savefig('binarySearch-curve-fit2.png')
plt.show()

# %% [markdown]
# The graph above shows the fitted curve for the worst case running time data for binary search. There is a clear log(x) relationship here, which is in line with the best case time complexity determined: Ω(log(N)).
#
# Despite the overall trend being visibly log(n), we can notice that the timings sometimes appear to be constant and then jump up to a new 'level'. This could be cause by some some lower-level details, eg. when the Python Virtual Machine code is being converted to C. Another possibility is that some information is being cached, leading to the running time levelling off, and then eventually being taken out of cache memory leading to a jump in running time.
#
# In addition, because the initial sequence passed to the binary search function was of length 200, we do not have any data from before this value for input size. We can however run this function again but this time using an initial sequence of length 1, in order to see the initial growth rate (see below):

# %%
seq = [1]          # new sequence of length 1
target = -15       # target is a number not in the sequence (eg. any negative number)   
res = get_timings_search(binarySearchIterative, seq, target, case = None, N = upperbound)
x_binary_worst2 = res[1]
y_binary_worst2 = res[0]

# %%
df_binary_worst2 = pd.DataFrame(list(zip(x_binary_worst2, y_binary_worst2)),
                               columns = ['x_binary_worst2', 'y_binary_worst2'])

# %%
ax = sns.lmplot(x="x_binary_worst2", y="y_binary_worst2", data=df_binary_worst2,
           logx=True, ci=None,line_kws={"color": 'r'},markers='+', scatter_kws={"s": 80, 'alpha':0.05})

ax.set(xlabel='Input size', ylabel='Running time [s]')
ax.fig.suptitle("         Worst case - Binary Search, from 0", fontsize=12)
#plt.savefig('binarySearch-curve-fit2.png')
plt.show()

# %% [markdown]
# Now we can see a clear log curve with very minimal error.

# %% [markdown]
# <h1>5. Unit Testing</h1>

# %%
class TestFactorial(unittest.TestCase):
    def test_fact_iter(self):
        f = fact_iter(5)
        self.assertEqual(f, 120)
        
    def test_fact_recursive_non_tail(self):
        f = fact_recursive_non_tail(5)
        self.assertEqual(f, 120)
        
    def test_fact_recursive_tail(self):
        f = fact_recursive_tail(5)
        self.assertEqual(f, 120)
        
        
class TestSearchAlgs(unittest.TestCase):
    def test_linear_search(self):
        sequence = [1, 2, 3, 4, 5, 6, 7]
        target = 5
        res = linearSearch(sequence, target)
        self.assertEqual(res, 4)    # target is at index 4
        
    def test_binary_search(self):
        sequence = [1, 2, 3, 4, 5, 6, 7]
        target = 5
        res = binarySearchIterative(sequence, target)
        self.assertEqual(res, 4)    # target is at index 4

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_fact_iter (__main__.TestFactorial) ... ok
# test_fact_recursive_non_tail (__main__.TestFactorial) ... ok
# test_fact_recursive_tail (__main__.TestFactorial) ... ok
# test_binary_search (__main__.TestSearchAlgs) ... ok
# test_linear_search (__main__.TestSearchAlgs) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.037s
#
# OK
